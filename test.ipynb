# %% [markdown]
# My first

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Test data
data = np.arange(10)
df = pd.DataFrame(data, columns=["Values"])

# Plot
plt.plot(df["Values"])
plt.title("Test Plot")
plt.show()
